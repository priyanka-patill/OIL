# %% [markdown]
# # 01 - Data Understanding & Inspection

# %%
import os, sys
sys.path.append("..")
from src.data_loader import inspect_workbook, load_raw_dataset

profile = inspect_workbook("../Indian_Refinery_Near_Miss_Datasets.xlsx")
print("Workbook profile:", profile.keys())
raw_df, summary_df = load_raw_dataset("../Indian_Refinery_Near_Miss_Datasets.xlsx")
print("Raw data shape:", raw_df.shape)
raw_df.head()

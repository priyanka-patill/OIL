# %% [markdown]
# # 03 - Leakage Audit & Target Validation

# %%
import os, sys
sys.path.append("..")
from src.data_loader import load_raw_dataset
from src.data_cleaning import clean_dataset
from src.leakage_audit import perform_leakage_audit

raw_df, _ = load_raw_dataset("../Indian_Refinery_Near_Miss_Datasets.xlsx")
cleaned_df = clean_dataset(raw_df)
audit = perform_leakage_audit(cleaned_df)
print("Leakage audit findings:", audit.keys())
